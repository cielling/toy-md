# %%
import numpy as np
import matplotlib.pyplot as plt
import math as m

# %%
eps = 1.0
sigma = 1.0
r_min = m.pow(2.0, 1/6.) * sigma
print(r_min)
# Out:
# 1.122462048309373

# %%
2.5*r_min
# Out:
# 2.8061551207734325

# %%
r = np.arange(1,500*sigma)/100
lj = 4*( np.power(sigma/r, 12.0) - np.power(sigma/r, 6.0))

# %%
plt.plot(r, lj)
plt.ylim(-1.1, 1.0)
plt.show()

# %%
lj
# Out:
# array([ 1.00000000e+24,  2.44140625e+20,  1.88167642e+18,  5.96046445e+16,
#         4.09599994e+15,  4.59393637e+14,  7.22476073e+13,  1.45519114e+13,
#         3.54070428e+12,  9.99999000e+11,  3.18630253e+11,  1.12156320e+11,
#         4.29217752e+10,  1.76384453e+10,  7.70725884e+09,  3.55265407e+09,
#         1.71633659e+09,  8.64400814e+08,  4.51789732e+08,  2.44125000e+08,
#         1.35934976e+08,  7.77819071e+07,  4.56248733e+07,  2.73767630e+07,
#         1.67731200e+07,  1.04757625e+07,  6.65988213e+06,  4.30421832e+06,
#         2.82465636e+06,  1.88030468e+06,  1.26845208e+06,  8.66430415e+05,
#         5.98785785e+05,  4.18390271e+05,  2.95382243e+05,  2.10583139e+05,
#         1.51517780e+05,  1.09973294e+05,  8.04810900e+04,  5.93605042e+04,
#         4.41088627e+04,  3.30079150e+04,  2.48670625e+04,  1.88540657e+04,
#         1.43823051e+04,  1.10349856e+04,  8.51371166e+03,  6.60329537e+03,
# ...
