# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import Axes3D
import pylab as pl
from IPython import display

# %%
file_name = "bld/my_particles-{:d}.csv"

# %%
# particles

# %%
NP = 100
D = 3
LL = 10
dt = 0.1
steps = 20

# %%
L = np.zeros([D]) + LL
L
# Out:
# array([10., 10., 10.])

# %%
def update():
    pass

# %%
fig = plt.gcf()
ax = plt.axes(projection = '3d')
ax.set_xlim(0, L[0])
ax.set_ylim(0, L[1])
ax.set_zlim(0, L[2])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
the_plot = ax.plot([], [], [], 'o')


for i in np.arange(0, steps + 1):
    particles = pd.read_csv(file_name.format(i))
    particles.set_index('id', inplace = True)
#     the_plot.set_paths([particles.x, particles.y, particles.z])
    the_plot[0].set_data_3d(particles.x.to_list(), particles.y.to_list(), particles.z.to_list())#, 'o')
    display.clear_output(wait=True)
    display.display(pl.gcf())
    plt.draw()

# %%
help(the_plot[0])
# Out:
# Help on Line3D in module mpl_toolkits.mplot3d.art3d object:
#
# class Line3D(matplotlib.lines.Line2D)
#  |  Line3D(xs, ys, zs, *args, **kwargs)
#  |
#  |  3D line object.
#  |
#  |  Method resolution order:
#  |      Line3D
#  |      matplotlib.lines.Line2D
#  |      matplotlib.artist.Artist
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, xs, ys, zs, *args, **kwargs)
#  |      Keyword arguments are passed onto :func:`~matplotlib.lines.Line2D`.
#  |
#  |  draw(self, renderer)
#  |      Draw the Artist (and its children) using the given renderer.
#  |
#  |      This has no effect if the artist is not visible (`.Artist.get_visible`
#  |      returns False).
#  |
#  |      Parameters
#  |      ----------
#  |      renderer : `.RendererBase` subclass.
#  |
#  |      Notes
#  |      -----
#  |      This method is overridden in the Artist subclasses.
#  |
#  |  get_data_3d(self)
#  |      Get the current data
#  |
#  |      Returns
#  |      -------
# ...
